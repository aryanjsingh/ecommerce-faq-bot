# %% [markdown]
# # Agentic AI Capstone Project: E-Commerce FAQ Bot
#
# ## 1. Written Summary
#
# **Domain:** E-Commerce Customer Support
#
# **What it does:** Handles common queries about returns, shipping, payments using a RAG pipeline and LangGraph agent.

# %%
# !pip install -r requirements.txt -q
